# %%
pwd
# Out:
# 'C:\\Users\\DELL'

# %%
import bs4
import re
import openpyxl as op
import datetime

# %% [markdown]
# # CORRECT DOCUMENT

# %% [markdown]
# # Extracting Italian Cuisine and order

# %%
def scrape_zomato(search):
    #url = 'https://www.swiggy.com/search?q='+search
    #url = 'https://www.swiggy.com/mumbai/restaurants'
    #data = open('D:\study\pycharmproj\pythonproj\pythonproj\italianzomato.html')
    print('hi')
    result = []
    wb = op.load_workbook('zomato3.xlsx')
    ws = wb.get_sheet_by_name('origin')
    for i in range(1,11):
            ##print('Italian Restaurants in Mumbai _ Page 1- Zomato_sneha 25-06-2019 4.55pm')
#         print('Thai Restaurants in Mumbai _ Page 1- Zomato_sneha 25-06-2019 3.35pm')
#         print('Italian Restaurants in Mumbai _ Page 1 - Zomato_sneha 25-06-2019 4.55pm')
    ##D:\Python\PYTHON PROJECT\25 june\25 june1

        name = 'D:\\study\\aegis\\python\\python-proj-release-1.0\\data\\ZOMATO\\9 july\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 09-07-2019 12.32pm.html'
        with open('D:\\study\\aegis\\python\\python-proj-release-1.0\\data\\ZOMATO\\9 july\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 09-07-2019 12.32pm.html','rb')as html:
        ##with open('D:\Python\PYTHON PROJECT\\25 june\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 25-06-2019 2.45pm.html','rb')as html:
        ##with open('D:\Python\PYTHON PROJECT\\24 june\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 24-06-2019 2.31pm.html','rb')as html:
        ##with open('D:\Python\PYTHON PROJECT\\24 june\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_SNEHA 24-06-2019 2.10PM.html','rb')as html:
        ##with open('C:\Sneha python\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 24-06-2019 2.20pm.html','rb')as html:
            soup = bs4.BeautifulSoup(html, 'html.parser')
    # print(soup)
    # for tag in soup.find_all('div'): # find all tag start with p
    #    print (tag.name)
        offer = soup.findAll('article', re.compile('search-result\s*'))
        
        # print(offer)
        for of in offer:
            # print(of)
            res =[search]
            if of.find('div', {'style': 'display:inline-flex;align-items: center;'}) or of.find('div',{'class':'search-page-text clearfix row'}).find('a',re.compile('\s*zgreen\s*')):
                res.append(of.find('a',re.compile('result-title hover_feedback zred bold ln24')).text)
                #print("in if")
                string = ''
                if(re.search('1',of.find('img').get('src'))):
                    string = string + 'gold 1+1 on food'
                elif(re.search('2',of.find('img').get('src'))):
                    string = string + 'gold 2+2 on drinks'
                if of.find('div', {'class': 'search-page-text clearfix row'}).find('a', re.compile('\s*zgreen\s*')):
                    if (string):
                        string = string + ','
                    string = string + of.find('div', {'class': 'search-page-text clearfix row'}).find('a', re.compile(
                        '\s*zgreen\s*')).text.strip()
                    #                     print(string)
                print(string)
                res.append(string)

                res.append(name[name.rindex(' ')-10:name.rindex(' ')])
                res.append(name[name.rindex(' ')+1:name.rindex('.')])
                result.append(res[:2])
                ws.append(res)
                print(res)
    wb.save('zomato3.xlsx')
    wb.close()
#     print(result)
    #return result

scrape_zomato('Italian')
# Out:
# hi
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
# gold 1+1 on food
# ['Italian', 'Prego - The Westin Mumbai Garden City\n                                    ', 'gold 1+1 on food', '09-07-2019', '12.32pm']
# gold 1+1 on food
# ['Italian', 'PizzaExpress\n                                    ', 'gold 1+1 on food', '09-07-2019', '12.32pm']
# gold 1+1 on food
# ['Italian', "Jamie's Pizzeria by Jamie Oliver\n                                    ", 'gold 1+1 on food', '09-07-2019', '12.32pm']
# gold 2+2 on drinks
# ['Italian', 'Mia Cucina\n                                    ', 'gold 2+2 on drinks', '09-07-2019', '12.32pm']
# gold 1+1 on food
# ['Italian', 'California Pizza Kitchen\n                                    ', 'gold 1+1 on food', '09-07-2019', '12.32pm']
# gold 1+1 on food
# ...

# %% [markdown]
# # Extracting Chinese Cuisine and Orders

# %%
def scrape_zomato(search):
    #url = 'https://www.swiggy.com/search?q='+search
    #url = 'https://www.swiggy.com/mumbai/restaurants'
    #data = open('D:\study\pycharmproj\pythonproj\pythonproj\italianzomato.html')
    print('hi')
    result = []
    wb = op.load_workbook('zomato3.xlsx')
    ws = wb.get_sheet_by_name('origin')
    for i in range(1,11):
            ##print('Italian Restaurants in Mumbai _ Page 1- Zomato_sneha 25-06-2019 4.55pm')
#         print('Thai Restaurants in Mumbai _ Page 1- Zomato_sneha 25-06-2019 3.35pm')
#         print('Italian Restaurants in Mumbai _ Page 1 - Zomato_sneha 25-06-2019 4.55pm')
    ##D:\Python\PYTHON PROJECT\25 june\25 june1
        name = 'D:\\study\\aegis\\python\\python-proj-release-1.0\\data\\ZOMATO\\9 july\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 09-07-2019 12.30pm.html'
        with open('D:\\study\\aegis\\python\\python-proj-release-1.0\\data\\ZOMATO\\9 july\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 09-07-2019 12.30pm.html','rb')as html:
        ##with open('D:\Python\PYTHON PROJECT\\25 june\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 25-06-2019 2.45pm.html','rb')as html:
        ##with open('D:\Python\PYTHON PROJECT\\24 june\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 24-06-2019 2.31pm.html','rb')as html:
        ##with open('D:\Python\PYTHON PROJECT\\24 june\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_SNEHA 24-06-2019 2.10PM.html','rb')as html:
        ##with open('C:\Sneha python\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 24-06-2019 2.20pm.html','rb')as html:
            soup = bs4.BeautifulSoup(html, 'html.parser')
    # print(soup)
    # for tag in soup.find_all('div'): # find all tag start with p
    #    print (tag.name)
        offer = soup.findAll('article', re.compile('search-result\s*'))
        
        # print(offer)
        for of in offer:
            # print(of)
            res =[search]
            if of.find('div', {'style': 'display:inline-flex;align-items: center;'}) or of.find('div',{'class':'search-page-text clearfix row'}).find('a',re.compile('\s*zgreen\s*')):
                res.append(of.find('a',re.compile('result-title hover_feedback zred bold ln24')).text)
                #print("in if")
                string = ''
                if(re.search('1',of.find('img').get('src'))):
                    string = string + 'gold 1+1 on food'
                elif(re.search('2',of.find('img').get('src'))):
                    string = string + 'gold 2+2 on drinks'
                if of.find('div', {'class': 'search-page-text clearfix row'}).find('a', re.compile('\s*zgreen\s*')):
                    if (string):
                        string = string + ','
                    string = string + of.find('div', {'class': 'search-page-text clearfix row'}).find('a', re.compile(
                        '\s*zgreen\s*')).text.strip()
                    #                     print(string)
                print(string)
                res.append(string)

                res.append(name[name.rindex(' ')-10:name.rindex(' ')])
                res.append(name[name.rindex(' ')+1:name.rindex('.')])
                result.append(res[:2])
                ws.append(res)
                print(res)
    wb.save('zomato3.xlsx')
    wb.close()
#     print(result)
    #return result

scrape_zomato('Chinese')
# Out:
# hi
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
# gold 1+1 on food
# ['Chinese', 'The Golden Wok\n                                    ', 'gold 1+1 on food', '09-07-2019', '12.30pm']
# gold 1+1 on food
# ['Chinese', 'China Bistro\n                                    ', 'gold 1+1 on food', '09-07-2019', '12.30pm']
# gold 1+1 on food
# ['Chinese', 'Shaollin Temple\n                                    ', 'gold 1+1 on food', '09-07-2019', '12.30pm']
# gold 1+1 on food
# ['Chinese', 'Mainland China\n                                    ', 'gold 1+1 on food', '09-07-2019', '12.30pm']
# gold 1+1 on food
# ['Chinese', 'Ming Yang - Taj Lands End\n                                    ', 'gold 1+1 on food', '09-07-2019', '12.30pm']
# gold 2+2 on drinks,15% off on your first order
# ...

# %% [markdown]
# # Extracting Mexican Cuisine and orders

# %%
def scrape_zomato(search):
    #url = 'https://www.swiggy.com/search?q='+search
    #url = 'https://www.swiggy.com/mumbai/restaurants'
    #data = open('D:\study\pycharmproj\pythonproj\pythonproj\italianzomato.html')
    print('hi')
    result = []
    wb = op.load_workbook('zomato3.xlsx')
    ws = wb.get_sheet_by_name('origin')
    for i in range(1,11):
            ##print('Italian Restaurants in Mumbai _ Page 1- Zomato_sneha 25-06-2019 4.55pm')
#         print('Thai Restaurants in Mumbai _ Page 1- Zomato_sneha 25-06-2019 3.35pm')
#         print('Italian Restaurants in Mumbai _ Page 1 - Zomato_sneha 25-06-2019 4.55pm')
    ##D:\Python\PYTHON PROJECT\25 june\25 june1
        name = 'D:\\study\\aegis\\python\\python-proj-release-1.0\\data\\ZOMATO\\9 july\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 09-07-2019 12.40pm.html'
        with open('D:\\study\\aegis\\python\\python-proj-release-1.0\\data\\ZOMATO\\9 july\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 09-07-2019 12.40pm.html','rb')as html:
        ##with open('D:\Python\PYTHON PROJECT\\25 june\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 25-06-2019 2.45pm.html','rb')as html:
        ##with open('D:\Python\PYTHON PROJECT\\24 june\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 24-06-2019 2.31pm.html','rb')as html:
        ##with open('D:\Python\PYTHON PROJECT\\24 june\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_SNEHA 24-06-2019 2.10PM.html','rb')as html:
        ##with open('C:\Sneha python\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 24-06-2019 2.20pm.html','rb')as html:
            soup = bs4.BeautifulSoup(html, 'html.parser')
    # print(soup)
    # for tag in soup.find_all('div'): # find all tag start with p
    #    print (tag.name)
        offer = soup.findAll('article', re.compile('search-result\s*'))
        
        # print(offer)
        for of in offer:
            # print(of)
            res =[search]
            if of.find('div', {'style': 'display:inline-flex;align-items: center;'}) or of.find('div',{'class':'search-page-text clearfix row'}).find('a',re.compile('\s*zgreen\s*')):
                res.append(of.find('a',re.compile('result-title hover_feedback zred bold ln24')).text)
                #print("in if")
                string = ''
                if(re.search('1',of.find('img').get('src'))):
                    string = string + 'gold 1+1 on food'
                elif(re.search('2',of.find('img').get('src'))):
                    string = string + 'gold 2+2 on drinks'
                if of.find('div', {'class': 'search-page-text clearfix row'}).find('a', re.compile('\s*zgreen\s*')):
                    if (string):
                        string = string + ','
                    string = string + of.find('div', {'class': 'search-page-text clearfix row'}).find('a', re.compile(
                        '\s*zgreen\s*')).text.strip()
                    #                     print(string)
                print(string)
                res.append(string)

                res.append(name[name.rindex(' ')-10:name.rindex(' ')])
                res.append(name[name.rindex(' ')+1:name.rindex('.')])
                result.append(res[:2])
                ws.append(res)
                print(res)
    wb.save('zomato3.xlsx')
    wb.close()
#     print(result)
    #return result

scrape_zomato('Mexican')
# Out:
# hi
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
# gold 1+1 on food
# ['Mexican', 'TAP\n                                    ', 'gold 1+1 on food', '09-07-2019', '12.40pm']
# gold 1+1 on food
# ['Mexican', 'Tamasha\n                                    ', 'gold 1+1 on food', '09-07-2019', '12.40pm']
# gold 2+2 on drinks,20% off on all orders above ₹200
# ['Mexican', "Chili's American Grill & Bar\n                                    ", 'gold 2+2 on drinks,20% off on all orders above ₹200', '09-07-2019', '12.40pm']
# gold 2+2 on drinks,15% off on all orders above ₹99
# ['Mexican', 'Jamjar Diner\n                                    ', 'gold 2+2 on drinks,15% off on all orders above ₹99', '09-07-2019', '12.40pm']
# gold 1+1 on food,15% off on your first order
# ...

# %% [markdown]
# # Extracting North Indian Cuisine and Offers

# %%
def scrape_zomato(search):
    #url = 'https://www.swiggy.com/search?q='+search
    #url = 'https://www.swiggy.com/mumbai/restaurants'
    #data = open('D:\study\pycharmproj\pythonproj\pythonproj\italianzomato.html')
    print('hi')
    result = []
    wb = op.load_workbook('zomato3.xlsx')
    ws = wb.get_sheet_by_name('origin')
    for i in range(1,11):
            ##print('Italian Restaurants in Mumbai _ Page 1- Zomato_sneha 25-06-2019 4.55pm')
#         print('Thai Restaurants in Mumbai _ Page 1- Zomato_sneha 25-06-2019 3.35pm')
#         print('Italian Restaurants in Mumbai _ Page 1 - Zomato_sneha 25-06-2019 4.55pm')
    ##D:\Python\PYTHON PROJECT\25 june\25 june1
        name = 'D:\\study\\aegis\\python\\python-proj-release-1.0\\data\\ZOMATO\\9 july\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 09-07-2019 12.37pm.html'
        with open('D:\\study\\aegis\\python\\python-proj-release-1.0\\data\\ZOMATO\\9 july\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 09-07-2019 12.37pm.html','rb')as html:
        ##with open('D:\Python\PYTHON PROJECT\\25 june\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 25-06-2019 2.45pm.html','rb')as html:
        ##with open('D:\Python\PYTHON PROJECT\\24 june\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 24-06-2019 2.31pm.html','rb')as html:
        ##with open('D:\Python\PYTHON PROJECT\\24 june\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_SNEHA 24-06-2019 2.10PM.html','rb')as html:
        ##with open('C:\Sneha python\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 24-06-2019 2.20pm.html','rb')as html:
            soup = bs4.BeautifulSoup(html, 'html.parser')
    # print(soup)
    # for tag in soup.find_all('div'): # find all tag start with p
    #    print (tag.name)
        offer = soup.findAll('article', re.compile('search-result\s*'))
        
        # print(offer)
        for of in offer:
            # print(of)
            res =[search]
            if of.find('div', {'style': 'display:inline-flex;align-items: center;'}) or of.find('div',{'class':'search-page-text clearfix row'}).find('a',re.compile('\s*zgreen\s*')):
                res.append(of.find('a',re.compile('result-title hover_feedback zred bold ln24')).text)
                #print("in if")
                string = ''
                if(re.search('1',of.find('img').get('src'))):
                    string = string + 'gold 1+1 on food'
                elif(re.search('2',of.find('img').get('src'))):
                    string = string + 'gold 2+2 on drinks'
                if of.find('div', {'class': 'search-page-text clearfix row'}).find('a', re.compile('\s*zgreen\s*')):
                    if (string):
                        string = string + ','
                    string = string + of.find('div', {'class': 'search-page-text clearfix row'}).find('a', re.compile(
                        '\s*zgreen\s*')).text.strip()
                    #                     print(string)
                print(string)
                res.append(string)

                res.append(name[name.rindex(' ')-10:name.rindex(' ')])
                res.append(name[name.rindex(' ')+1:name.rindex('.')])
                result.append(res[:2])
                ws.append(res)
                print(res)
    wb.save('zomato3.xlsx')
    wb.close()
#     print(result)
    #return result

scrape_zomato('North Indian')
# Out:
# hi
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
# gold 1+1 on food
# ['North Indian', 'Delhi Highway\n                                    ', 'gold 1+1 on food', '09-07-2019', '12.37pm']
# gold 2+2 on drinks
# ['North Indian', 'Punjab Grill\n                                    ', 'gold 2+2 on drinks', '09-07-2019', '12.37pm']
# gold 1+1 on food
# ['North Indian', 'Made In  Punjab\n                                    ', 'gold 1+1 on food', '09-07-2019', '12.37pm']
# gold 2+2 on drinks
# ['North Indian', 'Urban Tadka\n                                    ', 'gold 2+2 on drinks', '09-07-2019', '12.37pm']
# gold 2+2 on drinks,20% off on all orders above ₹199
# ['North Indian', 'Parathawala\n                                    ', 'gold 2+2 on drinks,20% off on all orders above ₹199', '09-07-2019', '12.37pm']
# gold 2+2 on drinks,11% off on all orders above ₹290
# ...

# %% [markdown]
# # Extracting Thai Cuisine and Offers

# %%
def scrape_zomato(search):
    #url = 'https://www.swiggy.com/search?q='+search
    #url = 'https://www.swiggy.com/mumbai/restaurants'
    #data = open('D:\study\pycharmproj\pythonproj\pythonproj\italianzomato.html')
    print('hi')
    result = []
    wb = op.load_workbook('zomato3.xlsx')
    ws = wb.get_sheet_by_name('origin')
    for i in range(1,11):
            ##print('Italian Restaurants in Mumbai _ Page 1- Zomato_sneha 25-06-2019 4.55pm')
#         print('Thai Restaurants in Mumbai _ Page 1- Zomato_sneha 25-06-2019 3.35pm')
#         print('Italian Restaurants in Mumbai _ Page 1 - Zomato_sneha 25-06-2019 4.55pm')
    ##D:\Python\PYTHON PROJECT\25 june\25 june1
        name = 'D:\\study\\aegis\\python\\python-proj-release-1.0\\data\\ZOMATO\\9 july\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 09-07-2019 12.35pm.html'
        with open('D:\\study\\aegis\\python\\python-proj-release-1.0\\data\\ZOMATO\\9 july\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 09-07-2019 12.35pm.html','rb')as html:
        ##with open('D:\Python\PYTHON PROJECT\\25 june\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 25-06-2019 2.45pm.html','rb')as html:
        ##with open('D:\Python\PYTHON PROJECT\\24 june\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 24-06-2019 2.31pm.html','rb')as html:
        ##with open('D:\Python\PYTHON PROJECT\\24 june\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_SNEHA 24-06-2019 2.10PM.html','rb')as html:
        ##with open('C:\Sneha python\\'+search+' Restaurants in Mumbai _ Page '+str(i)+' - Zomato_sneha 24-06-2019 2.20pm.html','rb')as html:
            soup = bs4.BeautifulSoup(html, 'html.parser')
    # print(soup)
    # for tag in soup.find_all('div'): # find all tag start with p
    #    print (tag.name)
        offer = soup.findAll('article', re.compile('search-result\s*'))
        
        # print(offer)
        for of in offer:
            # print(of)
            res =[search]
            if of.find('div', {'style': 'display:inline-flex;align-items: center;'}) or of.find('div',{'class':'search-page-text clearfix row'}).find('a',re.compile('\s*zgreen\s*')):
                res.append(of.find('a',re.compile('result-title hover_feedback zred bold ln24')).text)
                #print("in if")
                string = ''
                if(re.search('1',of.find('img').get('src'))):
                    string = string + 'gold 1+1 on food'
                elif(re.search('2',of.find('img').get('src'))):
                    string = string + 'gold 2+2 on drinks'
                if of.find('div', {'class': 'search-page-text clearfix row'}).find('a', re.compile('\s*zgreen\s*')):
                    if (string):
                        string = string + ','
                    string = string + of.find('div', {'class': 'search-page-text clearfix row'}).find('a', re.compile(
                        '\s*zgreen\s*')).text.strip()
                    #                     print(string)
                print(string)
                res.append(string)

                res.append(name[name.rindex(' ')-10:name.rindex(' ')])
                res.append(name[name.rindex(' ')+1:name.rindex('.')])
                result.append(res[:2])
                ws.append(res)
                print(res)
    wb.save('zomato3.xlsx')
    wb.close()
#     print(result)
    #return result

scrape_zomato('Thai')
# Out:
# hi
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
# gold 1+1 on food
# ['Thai', 'By the Mekong - The St. Regis Mumbai\n                                    ', 'gold 1+1 on food', '09-07-2019', '12.35pm']
# gold 1+1 on food,15% off on all orders above ₹199
# ['Thai', 'BusaGo\n                                    ', 'gold 1+1 on food,15% off on all orders above ₹199', '09-07-2019', '12.35pm']
# gold 2+2 on drinks,10% off on your first order
# ['Thai', 'Kung Fu Panda\n                                    ', 'gold 2+2 on drinks,10% off on your first order', '09-07-2019', '12.35pm']
# gold 2+2 on drinks
# ['Thai', 'Asia Kitchen By Mainland China\n                                    ', 'gold 2+2 on drinks', '09-07-2019', '12.35pm']
# gold 1+1 on food,15% off on all orders above ₹900
# ...

# %%
string = 'Italian Restaurants in Mumbai _ Page 2 - Zomato_sneha 25-06-2019 9.35pm'
string[string.rindex(' ')-10:string.rindex(' ')]
string[string.rindex(' ')+1:]
# Out:
# '9.35pm'
